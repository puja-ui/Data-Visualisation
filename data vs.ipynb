# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
sample_data = pd.read_csv('tcs codevista status.csv')

# %%
sample_data
# Out:
#         Unnamed: 0       Unnamed: 1                       Unnamed: 2  \
# 0        CT/DT ref             Name                     College Name
# 1    DT20184295720  AASHUTOSH SINHA  Silguri Institute Of Technology
# 2    DT20206836136    ABHINAV KUMAR  Silguri Institute Of Technology
# 3    DT20206833851      ABHIRUP ROY  Silguri Institute Of Technology
# 4    DT20206848139   ABHISHEK GHOSH  Silguri Institute Of Technology
# ..             ...              ...                              ...
# 392  DT20206873966   TATHAGATA SAHA  Silguri Institute Of Technology
# 393  CT20203321402  VAISHNAVI SONAR  Silguri Institute Of Technology
# 394  DT20206544303             VED   Silguri Institute Of Technology
# 395  DT20206874716      YUGAM ARYAN  Silguri Institute Of Technology
# 396  DT20206878224    ANIRUDDHA DAS  Silguri Institute Of Technology
#
#      Unnamed: 3                     Unnamed: 4 Unnamed: 5  \
# 0      phone no                       email id        YOP
# ...

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.iloc[2]
# Out:
# Unnamed: 0                      DT20206836136
# Unnamed: 1                      ABHINAV KUMAR
# Unnamed: 2    Silguri Institute Of Technology
# Unnamed: 3                         7479837849
# Unnamed: 4              abhikmr8051@gmail.com
# Unnamed: 5                               2021
# Unnamed: 6                                NaN
# Unnamed: 7                                NaN
# Unnamed: 8                                NaN
# Name: 2, dtype: object

# %%
sample_data.columns = ['a', 'b' , 'c', 'd' , 'e' , 'f' , 'g' , 'h' , 'i']

# %%
sample_data
# Out:
#                  a                b                                c  \
# 0        CT/DT ref             Name                     College Name
# 1    DT20184295720  AASHUTOSH SINHA  Silguri Institute Of Technology
# 2    DT20206836136    ABHINAV KUMAR  Silguri Institute Of Technology
# 3    DT20206833851      ABHIRUP ROY  Silguri Institute Of Technology
# 4    DT20206848139   ABHISHEK GHOSH  Silguri Institute Of Technology
# ..             ...              ...                              ...
# 392  DT20206873966   TATHAGATA SAHA  Silguri Institute Of Technology
# 393  CT20203321402  VAISHNAVI SONAR  Silguri Institute Of Technology
# 394  DT20206544303             VED   Silguri Institute Of Technology
# 395  DT20206874716      YUGAM ARYAN  Silguri Institute Of Technology
# 396  DT20206878224    ANIRUDDHA DAS  Silguri Institute Of Technology
#
#               d                              e     f                     g  \
# ...

# %%
myname = sample_data[sample_data.b == 'PUJA KARMAKAR']

# %%
myname
# Out:
#                  a              b                                c  \
# 340  DT20206863625  PUJA KARMAKAR  Silguri Institute Of Technology
#
#               d                     e     f    g    h    i
# 340  6294920083  pokepuja98@gmail.com  2023  NaN  NaN  NaN

# %%
sample_data.iloc[340]
# Out:
# a                      DT20206863625
# b                      PUJA KARMAKAR
# c    Silguri Institute Of Technology
# d                         6294920083
# e               pokepuja98@gmail.com
# f                               2023
# g                                NaN
# h                                NaN
# i                                NaN
# Name: 340, dtype: object

# %%
pr = sample_data[sample_data.h != 'NaN']

# %%
pr
# Out:
#                  a                b                                c  \
# 0        CT/DT ref             Name                     College Name
# 1    DT20184295720  AASHUTOSH SINHA  Silguri Institute Of Technology
# 2    DT20206836136    ABHINAV KUMAR  Silguri Institute Of Technology
# 3    DT20206833851      ABHIRUP ROY  Silguri Institute Of Technology
# 4    DT20206848139   ABHISHEK GHOSH  Silguri Institute Of Technology
# ..             ...              ...                              ...
# 392  DT20206873966   TATHAGATA SAHA  Silguri Institute Of Technology
# 393  CT20203321402  VAISHNAVI SONAR  Silguri Institute Of Technology
# 394  DT20206544303             VED   Silguri Institute Of Technology
# 395  DT20206874716      YUGAM ARYAN  Silguri Institute Of Technology
# 396  DT20206878224    ANIRUDDHA DAS  Silguri Institute Of Technology
#
#               d                              e     f                     g  \
# ...

# %%
head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b24701f77fd2> in <module>
# ----> 1 head(5)
#
# NameError: name 'head' is not defined

# %%
sample_data1 = pd.read_csv('sample_data.csv')

# %%
sample_data1
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data1)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data1.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sample_data1.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data1.column_c.iloc[2]
# Out:
# 6

# %%
plt.plot(sample_data1.column_a, sample_data1.column_b, 'o')
plt.plot(sample_data1.column_a, sample_data1.column_c)
plt.show()

# %%
data = pd.read_csv('countries.csv')

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# compare the population growth inthe US and china

# %%
us = data[data.country == 'United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = data[data.country == 'China']
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(us.year, china.population / 10**6)
plt.legend(["us", "china"])
plt.xlabel("year")
plt.ylabel("population")
plt.show()

# %%
us.population
# Out:
# 1608    157553000
# 1609    171984000
# 1610    186538000
# 1611    198712000
# 1612    209896000
# 1613    220239000
# 1614    232187835
# 1615    242803533
# 1616    256894189
# 1617    272911760
# 1618    287675526
# 1619    301139947
# Name: population, dtype: int64

# %%
us.population / us.population.iloc[0] * 100
# Out:
# 1608    100.000000
# 1609    109.159457
# 1610    118.396984
# 1611    126.123908
# 1612    133.222471
# 1613    139.787246
# 1614    147.371256
# 1615    154.109114
# 1616    163.052553
# 1617    173.219018
# 1618    182.589685
# 1619    191.135648
# Name: population, dtype: float64

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(us.year, china.population / china.population.iloc[0] * 100)
plt.legend(["us", "china"])
plt.xlabel("year")
plt.ylabel("population growth (first year = 100)")
plt.show()

# %%
tuber = pd.read_csv('tuber.csv')

# %%
tuber
# Out:
#           country iso2 iso3  iso_numeric  year measure unit age_group sex  \
# 0     Afghanistan   AF  AFG            4  2018     inc  num      0-14   a
# 1     Afghanistan   AF  AFG            4  2018     inc  num      0-14   f
# 2     Afghanistan   AF  AFG            4  2018     inc  num      0-14   m
# 3     Afghanistan   AF  AFG            4  2018     inc  num       0-4   f
# 4     Afghanistan   AF  AFG            4  2018     inc  num       0-4   m
# ...           ...  ...  ...          ...   ...     ...  ...       ...  ..
# 7280     Zimbabwe   ZW  ZWE          716  2018     inc  num       all   a
# 7281     Zimbabwe   ZW  ZWE          716  2018     inc  num       all   a
# 7282     Zimbabwe   ZW  ZWE          716  2018     inc  num       all   a
# 7283     Zimbabwe   ZW  ZWE          716  2018     inc  num       all   f
# 7284     Zimbabwe   ZW  ZWE          716  2018     inc  num       all   m
#
#      risk_factor   best       lo       hi
# ...

# %%
tbindia = tuber[tuber.country == 'India']

# %%
tbindia
# Out:
#      country iso2 iso3  iso_numeric  year measure unit age_group sex  \
# 3025   India   IN  IND          356  2018     inc  num      0-14   a
# 3026   India   IN  IND          356  2018     inc  num      0-14   f
# 3027   India   IN  IND          356  2018     inc  num      0-14   m
# 3028   India   IN  IND          356  2018     inc  num       0-4   f
# 3029   India   IN  IND          356  2018     inc  num       0-4   m
# 3030   India   IN  IND          356  2018     inc  num     15-24   f
# 3031   India   IN  IND          356  2018     inc  num     15-24   m
# 3032   India   IN  IND          356  2018     inc  num    15plus   a
# 3033   India   IN  IND          356  2018     inc  num    15plus   a
# 3034   India   IN  IND          356  2018     inc  num    15plus   a
# 3035   India   IN  IND          356  2018     inc  num    15plus   a
# 3036   India   IN  IND          356  2018     inc  num    15plus   f
# 3037   India   IN  IND          356  2018     inc  num    15plus   f
# ...

# %%
tbmale = tbindia[tbindia.sex == 'm']

# %%
tbmale
# Out:
#      country iso2 iso3  iso_numeric  year measure unit age_group sex  \
# 3027   India   IN  IND          356  2018     inc  num      0-14   m
# 3029   India   IN  IND          356  2018     inc  num       0-4   m
# 3031   India   IN  IND          356  2018     inc  num     15-24   m
# 3040   India   IN  IND          356  2018     inc  num    15plus   m
# 3041   India   IN  IND          356  2018     inc  num    15plus   m
# 3042   India   IN  IND          356  2018     inc  num    15plus   m
# 3043   India   IN  IND          356  2018     inc  num    15plus   m
# 3045   India   IN  IND          356  2018     inc  num     25-34   m
# 3047   India   IN  IND          356  2018     inc  num     35-44   m
# 3049   India   IN  IND          356  2018     inc  num     45-54   m
# 3051   India   IN  IND          356  2018     inc  num      5-14   m
# 3053   India   IN  IND          356  2018     inc  num     55-64   m
# 3055   India   IN  IND          356  2018     inc  num    65plus   m
# ...

# %%
tbfemale = tbindia[tbindia.sex == 'f']

# %%
tbfemale
# Out:
#      country iso2 iso3  iso_numeric  year measure unit age_group sex  \
# 3026   India   IN  IND          356  2018     inc  num      0-14   f
# 3028   India   IN  IND          356  2018     inc  num       0-4   f
# 3030   India   IN  IND          356  2018     inc  num     15-24   f
# 3036   India   IN  IND          356  2018     inc  num    15plus   f
# 3037   India   IN  IND          356  2018     inc  num    15plus   f
# 3038   India   IN  IND          356  2018     inc  num    15plus   f
# 3039   India   IN  IND          356  2018     inc  num    15plus   f
# 3044   India   IN  IND          356  2018     inc  num     25-34   f
# 3046   India   IN  IND          356  2018     inc  num     35-44   f
# 3048   India   IN  IND          356  2018     inc  num     45-54   f
# 3050   India   IN  IND          356  2018     inc  num      5-14   f
# 3052   India   IN  IND          356  2018     inc  num     55-64   f
# 3054   India   IN  IND          356  2018     inc  num    65plus   f
# ...

# %%
plt.plot(tbmale.age_group, tbmale.best,)
plt.plot(tbfemale.age_group, tbfemale.best,)
plt.legend(["male", "female"])
plt.xlabel("age group")
plt.ylabel("number of infected")
plt.show()
